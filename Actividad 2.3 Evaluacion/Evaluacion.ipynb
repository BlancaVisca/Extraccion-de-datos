# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#carga desde un archivo 
df = pd.read_csv('Copehnague.csv')
df
# Out:
#                         id                                       listing_url  \
# 0                    35797                https://www.airbnb.com/rooms/35797
# 1                    44616                https://www.airbnb.com/rooms/44616
# 2                    67703                https://www.airbnb.com/rooms/67703
# 3                    70644                https://www.airbnb.com/rooms/70644
# 4                   107078               https://www.airbnb.com/rooms/107078
# ...                    ...                                               ...
# 26577  1252141718111439700  https://www.airbnb.com/rooms/1252141718111439700
# 26578  1252159821531694005  https://www.airbnb.com/rooms/1252159821531694005
# 26579  1252185591721328995  https://www.airbnb.com/rooms/1252185591721328995
# 26580  1252218347521498445  https://www.airbnb.com/rooms/1252218347521498445
# 26581  1252229157495978163  https://www.airbnb.com/rooms/1252229157495978163
#
# ...

# %%
ejercicio1=df.head()
ejercicio1
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   35797   https://www.airbnb.com/rooms/35797  20240925021012   2024-09-25
# 1   44616   https://www.airbnb.com/rooms/44616  20240925021012   2024-09-26
# 2   67703   https://www.airbnb.com/rooms/67703  20240925021012   2024-09-26
# 3   70644   https://www.airbnb.com/rooms/70644  20240925021012   2024-09-25
# 4  107078  https://www.airbnb.com/rooms/107078  20240925021012   2024-09-25
#
#             source                                              name  \
# 0      city scrape                                       Villa Dante
# 1  previous scrape                                      Condesa Haus
# 2      city scrape                 2 bedroom apt. deco bldg, Condesa
# 3      city scrape  Beautiful light Studio Coyoacan- full equipped !
# 4      city scrape                                NEW  DESIGNER LOFT
#
#                                          description  \
# ...

# %%
ejercicio2 = df[df['HOST_SINCE'] < pd.to_datetime('2019-01-21')]
ejercicio2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\blanf\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HOST_SINCE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...
